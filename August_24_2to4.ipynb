# %%
passengers = ["Rahul Sharma", "Priya Patel", "Amit Verma"]

print("Passenger Reservation List:")
print(passengers)

print("\nFirst Passenger:", passengers[0])

print("Second Passenger:", passengers[1])

print("Third Passenger:", passengers[2])
# Out:
# Passenger Reservation List:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma']
#
# First Passenger: Rahul Sharma
# Second Passenger: Priya Patel
# Third Passenger: Amit Verma

# %%
train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Source": "Mumbai",
    "Destination": "Delhi",
    "Available_Seats": 120
}
train
# Out:
# {'Train_Number': 12951,
#  'Train_Name': 'Mumbai Rajdhani Express',
#  'Source': 'Mumbai',
#  'Destination': 'Delhi',
#  'Available_Seats': 120}

# %%
print("Train Information:")
print(train)

print("\nTrain Number:", train["Train_Number"])
print("Train Name:", train["Train_Name"])
print("Source Station:", train["Source"])
print("Destination Station:", train["Destination"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Information:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available_Seats': 120}
#
# Train Number: 12951
# Train Name: Mumbai Rajdhani Express
# Source Station: Mumbai
# Destination Station: Delhi
# Available Seats: 120

# %%
passengers[1:4]
# Out:
# ['Priya Patel', 'Amit Verma']

# %%
passengers[1:4:2]
# Out:
# ['Priya Patel']

# %%
passengers.append("Sneha Joshi")

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma', 'Sneha Joshi']

# %%
passengers.remove("Amit Verma")

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Sneha Joshi']

# %%
d = ["okk","done"]

# %%
passengers.extend(d)

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Sneha Joshi', 'okk', 'done']

# %%
passengers.pop()
# Out:
# 'done'

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Sneha Joshi', 'okk']

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Sneha Joshi', 'okk']

# %%
passengers.clear()

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma']

# %%
del passengers

# %%
passengers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 passengers
#
# NameError: name 'passengers' is not defined

# %%
passengers.count("okk2")
# Out:
# 0

# %%
passengers
# Out:
# ['Rahul Sharma', 'Priya Patel', 'Amit Verma']

# %%
passengers.index("Priya Patel")
# Out:
# 1

# %%
passengers.insert(1,"Rohan Mehta")

# %%
passengers
# Out:
# ['Rahul Sharma', 'Rohan Mehta', 'Priya Patel', 'Amit Verma']

# %%
removed_passenger = passengers.pop(2)
print(passengers)
# Out:
# ['Rahul Sharma', 'Rohan Mehta', 'Amit Verma']

# %%
t = ("wer",456 , "asd", 123 , 456)
t
# Out:
# ('wer', 456, 'asd', 123, 456)

# %%
t.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 t.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t.clear()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 t.clear()
#
# AttributeError: 'tuple' object has no attribute 'clear'

# %%
t
# Out:
# ('wer', 456, 'asd', 123, 456)

# %%
del t

# %%
t3 = {"wer",456 , "asd", 123 , 456}
t3
# Out:
# {123, 456, 'asd', 'wer'}

# %%
sett = {"Class1" , "class2" , 678 , 234 , 678}
we = {678 , 23232}
rt = {"class2"}

# %%
sett.issuperset(we)
# Out:
# False

# %%
sett.issuperset(rt)
# Out:
# True

# %%
rt.issuperset(sett)
# Out:
# False

# %%
rt.issubset(sett)
# Out:
# True

# %%
sett
# Out:
# {234, 678, 'Class1', 'class2'}

# %%
for y in sett:
    print(y)
# Out:
# Class1
# 234
# class2
# 678

# %%
sett
# Out:
# {234, 678, 'Class1', 'class2'}

# %%
sett.add("STUD")

# %%
sett
# Out:
# {234, 678, 'Class1', 'STUD', 'class2'}

# %%
sett.remove("Class1")

# %%
sett
# Out:
# {234, 678, 'STUD', 'class2'}

# %%
sett.pop()
# Out:
# 678

# %%
sett
# Out:
# {234, 'STUD', 'class2'}

# %%
sett.clear()

# %%
sett
# Out:
# set()

# %%
del sett

# %%
sett
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 sett
#
# NameError: name 'sett' is not defined

# %%
dss = {
    "NAME" : "Student2",
    "AGE" : 23,
    "Weight" : 65
}
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65}

# %%
dss["AGE"]
# Out:
# 23

# %%
dss["Age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 dss["Age"]
#
# KeyError: 'Age'

# %%
dss["Weight"]
# Out:
# 65

# %%
for y in dss:
    print(y)
# Out:
# NAME
# AGE
# Weight

# %%
for y in dss.items():
    print(y)
# Out:
# ('NAME', 'Student2')
# ('AGE', 23)
# ('Weight', 65)

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65}

# %%
dss.keys()
# Out:
# dict_keys(['NAME', 'AGE', 'Weight'])

# %%
dss.values()
# Out:
# dict_values(['Student2', 23, 65])

# %%
dss.items()
# Out:
# dict_items([('NAME', 'Student2'), ('AGE', 23), ('Weight', 65)])

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65}

# %%
dss.update({"City" : "Ahmedabad"})

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65, 'City': 'Ahmedabad'}

# %%
dss.update({"City" : "Pune"})

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65, 'City': 'Pune'}

# %%
dss.update({"City2" : "surat"})

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65, 'City': 'Pune', 'City2': 'surat'}

# %%
dss.discard("City2")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 dss.discard("City2")
#
# AttributeError: 'dict' object has no attribute 'discard'

# %%
dss.popitem()
# Out:
# ('City2', 'surat')

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65, 'City': 'Pune'}

# %%
dss.remove(["AGE"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 dss.remove(["AGE"])
#
# AttributeError: 'dict' object has no attribute 'remove'

# %%
dss
# Out:
# {'NAME': 'Student2', 'AGE': 23, 'Weight': 65, 'City': 'Pune'}

# %%
dss.discard("City")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 dss.discard("City")
#
# AttributeError: 'dict' object has no attribute 'discard'
