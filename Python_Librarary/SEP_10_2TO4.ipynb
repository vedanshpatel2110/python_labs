# %%
import numpy as np
import pandas as pd

# %%
e = np.array([5,1,7,9,2])
e
# Out:
# array([5, 1, 7, 9, 2])

# %%
e.ndim
# Out:
# 1

# %%
r = np.array(6)
print("R:",r)
print("DIM:", r.ndim)
# Out:
# R: 6
# DIM: 0

# %%
y = np.array([[3,7,1], [9,2,4]])
print("Y:",y)
print("DIM:", y.ndim)
# Out:
# Y: [[3 7 1]
#  [9 2 4]]
# DIM: 2

# %%
e = np.array([5,1,7,9,2])
print("E:",e)
print("0 INDEX:",e[0])
print("4 INDEX:",e[4])
# Out:
# E: [5 1 7 9 2]
# 0 INDEX: 5
# 4 INDEX: 2

# %%
y = np.array([[3,7,1], [9,2,4]])
print("Y:",y)
print("DIM:", y.ndim)
# Out:
# Y: [[3 7 1]
#  [9 2 4]]
# DIM: 2

# %%
y[0]
# Out:
# array([3, 7, 1])

# %%
y[0][2]
# Out:
# np.int64(1)

# %%
y[1]
# Out:
# array([9, 2, 4])

# %%
y[1][2]
# Out:
# np.int64(4)

# %%
y[0:2 , 1:]
# Out:
# array([[7, 1],
#        [2, 4]])

# %%
print("DIMENSION:",y.ndim)
print("Type Y:" , type(y))
print("DTYPE:" , y.dtype)
# Out:
# DIMENSION: 2
# Type Y: <class 'numpy.ndarray'>
# DTYPE: int64

# %%
print(y.astype("float"))
# Out:
# [[3. 7. 1.]
#  [9. 2. 4.]]

# %%
print(y.astype("str"))
# Out:
# [['3' '7' '1']
#  ['9' '2' '4']]

# %%
m = 7
print(m)
print(type(m))
print()
e = float(m)
print(e)
print(type(e))
# Out:
# 7
# <class 'int'>
#
# 7.0
# <class 'float'>

# %%
dss = pd.read_csv("/content/Retail_Dataset_Modified.csv")
dss
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 0        BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1      BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 0         Flagship     Pune     Tier1   Green Tea 100g    Groceries
# ...

# %%
type(dss)
# Out:
# pandas.core.frame.DataFrame

# %%
dss.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
dss["Store_Name"]
# Out:
# 0          BrandX_India Superstore Pune
# 1        BrandX_India Superstore Mumbai
# 2              BrandX_India Trends Pune
# 3           BrandX_India Trends Chennai
# 4          BrandX_India Connect Chennai
#                      ...
# 5166          BrandX_India Style Jaipur
# 5167          BrandX_India Daily Mumbai
# 5168    BrandX_India Gadget Zone Kanpur
# 5169          BrandX_India Style Mumbai
# 5170     BrandX_India Electronics Delhi
# Name: Store_Name, Length: 5171, dtype: object

# %%
type(dss["Store_Name"])
# Out:
# pandas.core.series.Series

# %%
dss.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
dss[['Store_Name', 'Brand_Name']]
# Out:
#                            Store_Name    Brand_Name
# 0        BrandX_India Superstore Pune  BrandX_India
# 1      BrandX_India Superstore Mumbai  BrandX_India
# 2            BrandX_India Trends Pune  BrandX_India
# 3         BrandX_India Trends Chennai  BrandX_India
# 4        BrandX_India Connect Chennai  BrandX_India
# ...                               ...           ...
# 5166        BrandX_India Style Jaipur  BrandX_India
# 5167        BrandX_India Daily Mumbai  BrandX_India
# 5168  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169        BrandX_India Style Mumbai  BrandX_India
# 5170   BrandX_India Electronics Delhi  BrandX_India
#
# [5171 rows x 2 columns]

# %%
type(dss[['Store_Name', 'Brand_Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
dss["Store_Name"][0].upper()   # INDEXING+STRING METHOD
# Out:
# 'BRANDX_INDIA SUPERSTORE PUNE'

# %%
len(dss["Store_Name"][0])
# Out:
# 28

# %%
dss
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 0        BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1      BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 0         Flagship     Pune     Tier1   Green Tea 100g    Groceries
# ...

# %%
dss.head(9)
# Out:
#          Store_ID                       Store_Name    Brand_Name  \
# 0     BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1   BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2     BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3  BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4  BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# 5    BX_DELHI_082    BrandX_India Superstore Delhi  BrandX_India
# 6   BX_MUMBAI_062  BrandX_India Accessories Mumbai  BrandX_India
# 7    BX_DELHI_062       BrandX_India Digital Delhi  BrandX_India
# 8   BX_MUMBAI_042   BrandX_India Appliances Mumbai  BrandX_India
#
#      Store_Type     City City_Tier     Product_Name         Category  \
# 0      Flagship     Pune     Tier1   Green Tea 100g        Groceries
# 1  Street Store   Mumbai     Metro  White Sugar 1kg        Groceries
# 2      Flagship     Pune     Tier1   Levi's T-Shirt          Clothes
# ...

# %%
dss.tail(9)
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 5162   BX_MUMBAI_067       BrandX_India Mobile Mumbai  BrandX_India
# 5163   BX_KANPUR_030      BrandX_India Digital Kanpur  BrandX_India
# 5164   BX_MUMBAI_020  BrandX_India Gadget Zone Mumbai  BrandX_India
# 5165  BX_CHENNAI_047       BrandX_India Fresh Chennai  BrandX_India
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type      City City_Tier      Product_Name     Category  \
# 5162  Street Store   Mumbai      Metro  Sony Alpha a7 IV      Gadgets
# 5163    Mall Store   KANPUR      Tier2         iPhone 14  Electronics
# 5164  Street Store   Mumbai      Metro    LG OLED 55Inch  Electronics
# ...

# %%
dss["Store_Name"][0:6]
# Out:
# 0      BrandX_India Superstore Pune
# 1    BrandX_India Superstore Mumbai
# 2          BrandX_India Trends Pune
# 3       BrandX_India Trends Chennai
# 4      BrandX_India Connect Chennai
# 5     BrandX_India Superstore Delhi
# Name: Store_Name, dtype: object

# %%
for t in dss["Store_Name"][0:6]:
  print(t)
# Out:
# BrandX_India Superstore Pune
# BrandX_India Superstore Mumbai
# BrandX_India Trends Pune
# BrandX_India Trends Chennai
# BrandX_India Connect Chennai
# BrandX_India Superstore Delhi

# %%
for t in dss["Store_Name"][0:6]:
  print(t.upper())
# Out:
# BRANDX_INDIA SUPERSTORE PUNE
# BRANDX_INDIA SUPERSTORE MUMBAI
# BRANDX_INDIA TRENDS PUNE
# BRANDX_INDIA TRENDS CHENNAI
# BRANDX_INDIA CONNECT CHENNAI
# BRANDX_INDIA SUPERSTORE DELHI

# %%
g = dss.select_dtypes(exclude="object")
g
# Out:
#       Unit_Price  Cost_Price  Profit_Margin  Average_Order_Value  \
# 0            305         239          21.64                  432
# 1             47          33          29.79                   63
# 2           2140        1715          19.86                 2994
# 3           3534        2894          18.11                 4416
# 4          50676       40467          20.15                54629
# ...          ...         ...            ...                  ...
# 5166        2373        1972          16.90                 2617
# 5167          54          43          20.37                   58
# 5168       75554       52990          29.86                94881
# 5169       11102        9267          16.53                16105
# 5170      117390       82950          29.34               166575
#
#       Inventory_Turnover  Days_of_Stock  Promotion_Impact  \
# 0                   2.30            156              23.1
# 1                   3.11            116              34.9
# ...

# %%
g2 = dss.select_dtypes(exclude="object").columns
g2
# Out:
# Index(['Unit_Price', 'Cost_Price', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Promotion_Impact',
#        'Max_Discount_Offered', 'Return_Rate', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competitor_Count', 'Brand_Loyalty',
#        'Brand_Awareness', 'Delivery_Time', 'Month', 'Year'],
#       dtype='object')

# %%
g["Unit_Price"]
# Out:
# 0          305
# 1           47
# 2         2140
# 3         3534
# 4        50676
#          ...
# 5166      2373
# 5167        54
# 5168     75554
# 5169     11102
# 5170    117390
# Name: Unit_Price, Length: 5171, dtype: int64

# %%
g["Unit_Price"][:10]
# Out:
# 0       305
# 1        47
# 2      2140
# 3      3534
# 4     50676
# 5       173
# 6     51299
# 7    103410
# 8     17070
# 9       808
# Name: Unit_Price, dtype: int64

# %%
g["Unit_Price"][:10].sum()
# Out:
# np.int64(229462)

# %%
max(g["Unit_Price"][:10])
# Out:
# 103410
