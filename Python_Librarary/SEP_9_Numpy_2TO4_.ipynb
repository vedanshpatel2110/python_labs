# %%
import numpy as np

# %%
ls = [3,6,9,"okk" , "done"]
ls
# Out:
# [3, 6, 9, 'okk', 'done']

# %%
ls * 2
# Out:
# [3, 6, 9, 'okk', 'done', 3, 6, 9, 'okk', 'done']

# %%
e = np.array([2,8,5,9])
e
# Out:
# array([2, 8, 5, 9])

# %%
t = np.array([4 , 8, 1, 9.4 ])
t
# Out:
# array([4. , 8. , 1. , 9.4])

# %%
m = np.array(["okk" , "done" , "verify"])
m
# Out:
# array(['okk', 'done', 'verify'], dtype='<U6')

# %%
e = np.array([2,8,5,9])
print("E :" , e)
print("TYPE:" , type(e))
print("DTYPE : " , e.dtype)
# Out:
# E : [2 8 5 9]
# TYPE: <class 'numpy.ndarray'>
# DTYPE :  int64

# %%
e2 = np.array([2 ,8 ,5.3 ,9 ])
print("E2 :" , e2)
print("TYPE e2:" , type(e2))
print("DTYPE : " , e2.dtype)
# Out:
# E2 : [2.  8.  5.3 9. ]
# TYPE e2: <class 'numpy.ndarray'>
# DTYPE :  float64

# %%
import pandas as pd

# %%
data = pd.read_csv("/content/Retail_Dataset_Modified.csv")
data
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 0        BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1      BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2        BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3     BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4     BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# ...              ...                              ...           ...
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 0         Flagship     Pune     Tier1   Green Tea 100g    Groceries
# ...

# %%
data.head()
# Out:
#          Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0     BX_PUNE_034    BrandX_India Superstore Pune  BrandX_India      Flagship
# 1   BX_MUMBAI_023  BrandX_India Superstore Mumbai  BrandX_India  Street Store
# 2     BX_PUNE_073        BrandX_India Trends Pune  BrandX_India      Flagship
# 3  BX_CHENNAI_061     BrandX_India Trends Chennai  BrandX_India    Mall Store
# 4  BX_CHENNAI_033    BrandX_India Connect Chennai  BrandX_India    Mall Store
#
#       City City_Tier     Product_Name   Category     Sub_Category  \
# 0     Pune     Tier1   Green Tea 100g  Groceries              Tea
# 1   Mumbai     Metro  White Sugar 1kg  Groceries            Sugar
# 2     Pune     Tier1   Levi's T-Shirt    Clothes         T-Shirts
# 3  Chennai     Metro    Adidas Hoodie    Clothes          Jackets
# 4  Chennai     Metro    PlayStation 5    Gadgets  Gaming Consoles
#
#   Product_Stage  ... Brand_Loyalty Brand_Awareness  Price_Competitiveness  \
# ...

# %%
data.head(3)
# Out:
#         Store_ID                      Store_Name    Brand_Name    Store_Type  \
# 0    BX_PUNE_034    BrandX_India Superstore Pune  BrandX_India      Flagship
# 1  BX_MUMBAI_023  BrandX_India Superstore Mumbai  BrandX_India  Street Store
# 2    BX_PUNE_073        BrandX_India Trends Pune  BrandX_India      Flagship
#
#      City City_Tier     Product_Name   Category Sub_Category Product_Stage  \
# 0    Pune     Tier1   Green Tea 100g  Groceries          Tea     Declining
# 1  Mumbai     Metro  White Sugar 1kg  Groceries        Sugar     Declining
# 2    Pune     Tier1   Levi's T-Shirt    Clothes     T-Shirts     Declining
#
#    ... Brand_Loyalty Brand_Awareness  Price_Competitiveness  Weather_Impact  \
# 0  ...          70.8            75.7               Standard             Low
# 1  ...          80.5            81.5            Competitive             Low
# 2  ...          68.5            76.7               Standard          Medium
#
# ...

# %%
data.head(9)
# Out:
#          Store_ID                       Store_Name    Brand_Name  \
# 0     BX_PUNE_034     BrandX_India Superstore Pune  BrandX_India
# 1   BX_MUMBAI_023   BrandX_India Superstore Mumbai  BrandX_India
# 2     BX_PUNE_073         BrandX_India Trends Pune  BrandX_India
# 3  BX_CHENNAI_061      BrandX_India Trends Chennai  BrandX_India
# 4  BX_CHENNAI_033     BrandX_India Connect Chennai  BrandX_India
# 5    BX_DELHI_082    BrandX_India Superstore Delhi  BrandX_India
# 6   BX_MUMBAI_062  BrandX_India Accessories Mumbai  BrandX_India
# 7    BX_DELHI_062       BrandX_India Digital Delhi  BrandX_India
# 8   BX_MUMBAI_042   BrandX_India Appliances Mumbai  BrandX_India
#
#      Store_Type     City City_Tier     Product_Name         Category  \
# 0      Flagship     Pune     Tier1   Green Tea 100g        Groceries
# 1  Street Store   Mumbai     Metro  White Sugar 1kg        Groceries
# 2      Flagship     Pune     Tier1   Levi's T-Shirt          Clothes
# ...

# %%
data.tail()
# Out:
#            Store_ID                       Store_Name    Brand_Name  \
# 5166  BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167  BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168  BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169  BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170   BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type     City City_Tier     Product_Name     Category  \
# 5166  Street Store  Jaipur      Tier2       Pepe Jeans      Clothes
# 5167       Express  Mumbai      Metro  White Sugar 1kg    Groceries
# 5168      Flagship  Kanpur      Tier2      Dell XPS 13  Electronics
# 5169  Street Store  Mumbai      Metro     Nike Air Max      Clothes
# 5170      Flagship   Delhi      Metro   MacBook Air M2  Electronics
#
#      Sub_Category Product_Stage  ... Brand_Loyalty Brand_Awareness  \
# 5166        Jeans     Declining  ...          91.3            68.7
# ...

# %%
data.tail(7)
# Out:
#             Store_ID                       Store_Name    Brand_Name  \
# 5164   BX_MUMBAI_020  BrandX_India Gadget Zone Mumbai  BrandX_India
# 5165  BX_CHENNAI_047       BrandX_India Fresh Chennai  BrandX_India
# 5166   BX_JAIPUR_077        BrandX_India Style Jaipur  BrandX_India
# 5167   BX_MUMBAI_067        BrandX_India Daily Mumbai  BrandX_India
# 5168   BX_KANPUR_097  BrandX_India Gadget Zone Kanpur  BrandX_India
# 5169   BX_MUMBAI_031        BrandX_India Style Mumbai  BrandX_India
# 5170    BX_DELHI_032   BrandX_India Electronics Delhi  BrandX_India
#
#         Store_Type      City City_Tier     Product_Name     Category  \
# 5164  Street Store   Mumbai      Metro   LG OLED 55Inch  Electronics
# 5165    Online Hub  Chennai      Metro    Moong Dal 1kg    Groceries
# 5166  Street Store   Jaipur      Tier2       Pepe Jeans      Clothes
# 5167       Express   Mumbai      Metro  White Sugar 1kg    Groceries
# 5168      Flagship   Kanpur      Tier2      Dell XPS 13  Electronics
# ...

# %%
data.shape   # row  , columns
# Out:
# (5171, 47)

# %%
data.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Store_ID', 'Store_Name', 'Brand_Name', 'Store_Type', 'City',
#        'City_Tier', 'Product_Name', 'Category', 'Sub_Category',
#        'Product_Stage', 'Quantity_Available', 'Units_Sold', 'Unit_Price',
#        'Cost_Price', 'Revenue', 'Profit_Margin', 'Average_Order_Value',
#        'Inventory_Turnover', 'Days_of_Stock', 'Customer_Segment',
#        'Sales_Channel', 'Payment_Method', 'Supplier', 'Supplier_Rating',
#        'Promotion_Type', 'Promotion_Impact', 'Max_Discount_Offered',
#        'Return_Rate', 'Return_Reason', 'Customer_Satisfaction',
#        'Online_Rating', 'Review_Count', 'Sales_Rep_Experience',
#        'Sales_Rep_Rating', 'Market_Share', 'Competition_Level',
#        'Competitor_Count', 'Brand_Loyalty', 'Brand_Awareness',
#        'Price_Competitiveness', 'Weather_Impact', 'Delivery_Time',
#        'Shipping_Cost', 'Month', 'Year', 'Quarter', 'Season'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5171 entries, 0 to 5170
# Data columns (total 47 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Store_ID               5171 non-null   object
#  1   Store_Name             5171 non-null   object
#  2   Brand_Name             5171 non-null   object
#  3   Store_Type             5171 non-null   object
#  4   City                   5109 non-null   object
#  5   City_Tier              5171 non-null   object
#  6   Product_Name           5098 non-null   object
#  7   Category               5171 non-null   object
#  8   Sub_Category           5171 non-null   object
#  9   Product_Stage          5171 non-null   object
#  10  Quantity_Available     5171 non-null   object
#  11  Units_Sold             5171 non-null   object
#  12  Unit_Price             5171 non-null   int64
#  13  Cost_Price             5171 non-null   int64
# ...

# %%
dss = pd.read_csv("/content/titanic (1).csv")
dss
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
de = pd.read_excel("/content/Excel+LAB+7+Dataset_Dmart.xlsx")
de
# Out:
#         order_id Order_Month order_date region    sales       category  \
# 0      ORD100000       March 2023-03-30   East   713.49       Clothing
# 1      ORD100001      August 2023-08-28   West  3802.97    Electronics
# 2      ORD100002       March 2024-03-09  North  3588.97      Home Care
# 3      ORD100003     October 2024-10-13   East  1160.86    Electronics
# 4      ORD100004       April 2023-04-06   East  3071.32    Electronics
# ...          ...         ...        ...    ...      ...            ...
# 15340  ORD115340    November 2023-11-02  North  2910.33       Clothing
# 15341  ORD115341        July 2023-07-22   West  2723.39       Clothing
# 15342  ORD115342        June 2023-06-04  North  2400.38    Electronics
# 15343  ORD115343    February 2024-02-20   East  2978.52  Personal Care
# 15344  ORD115344    November 2023-11-18  South  4984.32        Grocery
#
#        discount  quantity delivery_date customer_type payment_mode  profit  \
# ...

# %%
idd = [123,456,789,2926]
name = ["Diva" , "Mahesh" , "Rakesh" , "Vikky"]
age = [20,25,18,10]

vb = pd.DataFrame({"IDD" : idd , "NAME" : name , "AGE" : age})
vb
# Out:
#     IDD    NAME  AGE
# 0   123    Diva   20
# 1   456  Mahesh   25
# 2   789  Rakesh   18
# 3  2926   Vikky   10

# %%
#idd = [123,456,789,2926]
name = ["Diva" , "Mahesh" , "Rakesh" , "Vikky"]
age = [20,25,18,10]

vb2 = pd.DataFrame({"NAME2" : name , "AGE2" : age})
vb2
# Out:
#     NAME2  AGE2
# 0    Diva    20
# 1  Mahesh    25
# 2  Rakesh    18
# 3   Vikky    10

# %%
type(vb2)
# Out:
# pandas.core.frame.DataFrame

# %%
idd = [123,456,789,2926]
name = ["Diva" , "Mahesh" , "Rakesh" , "Vikky"]
age = [20,25,18,10]

# %%
m = pd.Series(idd)
m
# Out:
# 0     123
# 1     456
# 2     789
# 3    2926
# dtype: int64

# %%
m3 = pd.Series(age,idd)
m3
# Out:
# 123     20
# 456     25
# 789     18
# 2926    10
# dtype: int64

# %%
m3.shape
# Out:
# (4,)

# %%
data.shape
# Out:
# (5171, 47)

# %%
vb
# Out:
#     IDD    NAME  AGE
# 0   123    Diva   20
# 1   456  Mahesh   25
# 2   789  Rakesh   18
# 3  2926   Vikky   10

# %%
vb.isnull()
# Out:
#      IDD   NAME    AGE
# 0  False  False  False
# 1  False  False  False
# 2  False  False  False
# 3  False  False  False

# %%
vb.isnull().sum()
# Out:
# IDD     0
# NAME    0
# AGE     0
# dtype: int64

# %%
idd3 = [123,np.nan,2926]
name3 = ["Diva" , "Rakesh" , "Vikky"]
age3 = [20,25,18]

vb3 = pd.DataFrame({"IDD3" : idd3 , "NAME3" : name3 , "AGE3" : age3})
vb3
# Out:
#      IDD3   NAME3  AGE3
# 0   123.0    Diva    20
# 1     NaN  Rakesh    25
# 2  2926.0   Vikky    18

# %%
vb3.isnull()
# Out:
#     IDD3  NAME3   AGE3
# 0  False  False  False
# 1   True  False  False
# 2  False  False  False
