# %%
class Car:
    print("Hello")

d = Car()
print(d)
# Out:
# Hello
# ...

# %%
def abc():
    print("okkk")

# %%
abc()
# Out:
# okkk

# %%
w = Car()
print(w)

# %%
n = Car()

# %%
print(n)

# %%
class Car:

    def deta(self):
        print(self.color)
        print(self.price)
        print(self.model)

nm = Car()

# %%
nm.color = "Black"
nm.price = 10000000
nm.model = "SDSD123"

# %%
nm.deta()
# Out:
# Black
# 10000000
# SDSD123

# %%
nm2 = Car()

# %%
nm2.color = "Red"
nm2.price = 2000000
nm2.model = "awaw234"

# %%
nm2.deta()
# Out:
# Red
# 2000000
# awaw234

# %%
class Car2:
    price = 1000000

    def prr(self):
        print("Updated Car Price " , self.price-100000)

# %%
er = Car2()
er.prr()
# Out:
# Updated Car Price  900000

# %%
class Car3:
    def __init__(self , amount):
        self.__amount = amount

    def total(self):
        print("Total Amount ", self.__amount)

    def depo(self , amt):
        self.__amount += amt
        print("Finalize depo : " , self.__amount)

# %%
t = Car3(10000)
t.total()
# Out:
# Total Amount  10000

# %%
t.depo(200)
# Out:
# Finalize depo :  10200

# %%
class Car5:
    def __init__(self , amount1):
        self.amount1 = amount1

    def total(self):
        print("Total Amount ", self.amount1)

    def depo(self , amt1):
        self.amount1 += amt1
        print("Finalize depo : " , self.amount1)

# %%
g = Car5(5000)
g.total()
# Out:
# Total Amount  5000

# %%
g.depo(300)
# Out:
# Finalize depo :  5300

# %%
print(g.amount1)
# Out:
# 5300

# %%
class Car7:
    def __init__(self , amount):
        self.__amount = amount

    def total(self):
        print("Total Amount : ", self.__amount)

    def depo(self , amt):
        self.__amount += amt
        print("Finalize depo : " , self.__amount)

# %%
w = Car7(3000)
w.total()
# Out:
# Total Amount :  3000

# %%
w.depo(130)
# Out:
# Finalize depo :  3130

# %%
print(w.amount)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 print(w.amount)
#
# AttributeError: 'Car7' object has no attribute 'amount'

# %% [markdown]
# # File Handling

# %%
d = open("SEP_1.txt" , "x")
d.close()

# %%
q2 = open("SEP_1.txt" , "r")
print(q2.read())
q2.close()
# Out:
# This is Our
# File Handling
# Topic

# %%
q.read()
# Out:
# ''

# %%
q.close()

# %%
q2 = open("SEP_1.txt" , "w")
q2.write("OKAY GOT IT THAT CODE!!!!!!!!")
q2.close()

# %%
q2 = open("SEP_1.txt" , "r")
print(q2.read())
q2.close()
# Out:
# OKAY GOT IT THAT CODE!!!!!!!!

# %%
q2 = open("SEP_1.txt" , "a")
q2.write("\nnow code is addeded againOKAY GOT IT THAT CODE!!!!!!!!")
q2.close()

# %%
q2 = open("SEP_1.txt" , "w")
q2.write("   nottttt       ")
q2.close()

# %%
class Car:
    speed = 120

    def show_speed(self):
        print("Speed :", self.speed)

car1 = Car()
car1.show_speed()
# Out:
# Speed : 120

# %%
class Car:

    def start(self):
        print("Car Started")

car1 = Car()
car1.start()
# Out:
# Car Started
